# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# # 4.2 데이터 입출력

# %% [markdown]
# ## %%writefile 명령

# %%
# %%writefile sample.csv
# c1, c2, c3
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, trhee
# Out:
# Overwriting sample.csv

# %% [markdown]
# ## CSV 파일입력

# %%
pd.read_csv('sample.csv')
# Out:
#    c1    c2      c3
# 0   1  1.11     one
# 1   2  2.22     two
# 2   3  3.33   trhee

# %%
# %%writefile sample2.csv
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# Out:
# Overwriting sample2.csv

# %%
pd.read_csv('sample2.csv',names=['c1','c2','c3'])
# Out:
#    c1    c2      c3
# 0   1  1.11     one
# 1   2  2.22     two
# 2   3  3.33   three

# %%
pd.read_csv('sample.csv',index_col='c1') ##특정한 열을 행 인덱스로 지정 index_col
# Out:
#       c2      c3
# c1
# 1   1.11     one
# 2   2.22     two
# 3   3.33   trhee

# %%
# %%writefile sample3.txt
# c1       c2        c3        c4
# 0.179181 -1.538472 1.347553  0.43381
# 1.024209 0.087307  -1.281997 0.49265
# 0.417889 -2.002308 0.255245  -1.10515
# Out:
# Overwriting sample3.txt

# %%
pd.read_table('sample3.txt', sep='\s+')
# Out:
#          c1        c2        c3       c4
# 0  0.179181 -1.538472  1.347553  0.43381
# 1  1.024209  0.087307 -1.281997  0.49265
# 2  0.417889 -2.002308  0.255245 -1.10515

# %%
# %%writefile sample4.txt
# 파일 제목 : sample4.txt
# 데이터 포맷의 설명:
# c1, c2, c3
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# Out:
# Overwriting sample4.txt

# %%
pd.read_csv('sample4.txt', skiprows=[0,1]) ## skiporws로 뛰어 행 뛰어넘기
# Out:
#    c1    c2      c3
# 0   1  1.11     one
# 1   2  2.22     two
# 2   3  3.33   three

# %%
# %%writefile sample5.csv
# c1,c2,c3
# 1, 1.11, one
# 2,  , two
# 누락, 3.33, three
# Out:
# Overwriting sample5.csv

# %%
df = pd.read_csv('sample5.csv',na_values=['누락'])
df
# Out:
#     c1     c2      c3
# 0  1.0   1.11     one
# 1  2.0            two
# 2  NaN   3.33   three

# %% [markdown]
# ## csv 파일 출력

# %%
df.to_csv('sample6.csv')

# %%
# !type sample6.csv
# Out:
# ,c1,c2,c3
# 0,1.0, 1.11, one
# 1,2.0,  , two
# 2,, 3.33, three

# %%
# !type sample3.txt
# Out:
# c1       c2        c3        c4
# 0.179181 -1.538472 1.347553  0.43381
# 1.024209 0.087307  -1.281997 0.49265
# 0.417889 -2.002308 0.255245  -1.10515

# %%
df.index =["a","b","c"]
df
# Out:
#     c1     c2      c3
# a  1.0   1.11     one
# b  2.0            two
# c  NaN   3.33   three

# %% [markdown]
# ## 인터넷 상의 csv 파일입력

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datascienceschool/docker_rpython/master/data/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.set_option("display.max_rows",20)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
import datetime

# %%
dt_start = datetime.datetime(2015, 1,1)
dt_end = "2016, 6, 30"

# %%
# !pip install pandas_datareader
## pandas_datareader 설치

# %%
import pandas_datareader as pdr

gdp = pdr.get_data_fred('GDP', dt_start, dt_end)
gdp.tail()
# Out:
#                   GDP
# DATE
# 2015-04-01  18193.707
# 2015-07-01  18306.960
# 2015-10-01  18332.079
# 2016-01-01  18425.306
# 2016-04-01  18611.617

# %%
inflation = pdr.get_data_fred(["CPIAUCSL", "CPILFESL"], dt_start, dt_end)
inflation.tail()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2016-02-01   237.336   245.510
# 2016-03-01   238.080   245.913
# 2016-04-01   238.992   246.551
# 2016-05-01   239.557   247.137
# 2016-06-01   240.222   247.540

# %%
pip install -U finance-datareader
# Out:
# ...
#
# ...

# %%
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.50'

# %%
df_krx = fdr.StockListing('KRX')
df_krx.head()
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        60200          1      800
# 1  373220  KR7373220003  LG에너지솔루션  KOSPI       587000          2    -5000
# 2  207940  KR7207940008  삼성바이오로직스  KOSPI       885000          1    14000
# 3  000660  KR7000660001    SK하이닉스  KOSPI        86400          1     1900
# 4  006400  KR7006400006     삼성SDI  KOSPI       739000          1     6000
#
#    ChagesRatio    Open    High     Low   Volume        Amount  \
# 0         1.35   59700   60300   59400  9254684  555911600400
# 1        -0.84  591000  596000  581000   188177  110561299000
# 2         1.61  879000  886000  870000    31391   27545514000
# 3         2.25   85400   86500   85000  1926176  165625154300
# 4         0.82  742000  749000  733000   179538  132980470000
#
#             Marcap      Stocks MarketId
# 0  359380909510000  5969782550      STK
# 1  137358000000000   234000000      STK
# ...

# %%
df = fdr.DataReader('BTC/KRW', '2016')
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
