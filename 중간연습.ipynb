# %% [markdown]
# # 데이터 확인

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
df = pd.read_csv("kaggle_survey_2020_responses.csv", low_memory=False)
df
# Out:
#       Time from Start to Finish (seconds)  ...                                        Q35_B_OTHER
# 0                   Duration (in seconds)  ...  In the next 2 years, do you hope to become mor...
# 1                                    1838  ...                                                NaN
# 2                                  289287  ...                                                NaN
# 3                                     860  ...                                                NaN
# 4                                     507  ...                                                NaN
# ...                                   ...  ...                                                ...
# 20032                                 126  ...                                                NaN
# 20033                                 566  ...                                                NaN
# 20034                                 238  ...                                                NaN
# ...

# %%
question = df.loc[0]
question
# Out:
# Time from Start to Finish (seconds)                                Duration (in seconds)
# Q1                                                           What is your age (# years)?
# Q2                                                What is your gender? - Selected Choice
# Q3                                             In which country do you currently reside?
# Q4                                     What is the highest level of formal education ...
#                                                              ...
# Q35_B_Part_7                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_8                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_9                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_10                          In the next 2 years, do you hope to become mor...
# Q35_B_OTHER                            In the next 2 years, do you hope to become mor...
# ...

# %%
answer = df.drop(0)
answer
# Out:
#       Time from Start to Finish (seconds)     Q1  ... Q35_B_Part_10 Q35_B_OTHER
# 1                                    1838  35-39  ...           NaN         NaN
# 2                                  289287  30-34  ...           NaN         NaN
# 3                                     860  35-39  ...          None         NaN
# 4                                     507  30-34  ...           NaN         NaN
# 5                                      78  30-34  ...           NaN         NaN
# ...                                   ...    ...  ...           ...         ...
# 20032                                 126  18-21  ...           NaN         NaN
# 20033                                 566  55-59  ...          None         NaN
# 20034                                 238  30-34  ...           NaN         NaN
# 20035                                 625  22-24  ...           NaN         NaN
# 20036                                1031  22-24  ...           NaN         NaN
#
# ...

# %%
answer.sort_values("Q1")
# Out:
#       Time from Start to Finish (seconds)     Q1  ... Q35_B_Part_10 Q35_B_OTHER
# 6079                                   33  18-21  ...           NaN         NaN
# 13969                                 408  18-21  ...           NaN         NaN
# 13964                                 540  18-21  ...           NaN       Other
# 8718                                  108  18-21  ...           NaN         NaN
# 13958                                 290  18-21  ...           NaN         NaN
# ...                                   ...    ...  ...           ...         ...
# 10784                                6704    70+  ...           NaN       Other
# 13661                                 357    70+  ...           NaN         NaN
# 5776                                  876    70+  ...          None         NaN
# 8979                                  756    70+  ...          None         NaN
# 19824                                1720    70+  ...           NaN         NaN
#
# ...

# %%
sns.countplot(data=answer.sort_values("Q1"), x="Q1", palette="Blues_r").set_title(question["Q1"])
# Out:
# Text(0.5, 1.0, 'What is your age (# years)?')

# %%
sns.countplot(data=answer, y="Q2", palette="Blues_r").set_title(question["Q2"])
# Out:
# Text(0.5, 1.0, 'What is your gender? - Selected Choice')

# %%
answer.dtypes
# Out:
# Time from Start to Finish (seconds)    object
# Q1                                     object
# Q2                                     object
# Q3                                     object
# Q4                                     object
#                                         ...
# Q35_B_Part_7                           object
# Q35_B_Part_8                           object
# Q35_B_Part_9                           object
# Q35_B_Part_10                          object
# Q35_B_OTHER                            object
# Length: 355, dtype: object

# %%
def show_countplot(question_number,order=None):
  if not order:
    order = answer[question_number].value_counts().index
  plt.figure(figsize=(10,8))
  sns.countplot(data=answer, y=question_number, order=order, palette="Blues_r").set_title(question[question_number])

# %%
answer["Q1"].value_counts()
# Out:
# 25-29    4011
# 22-24    3786
# 18-21    3469
# 30-34    2811
# 35-39    1991
# 40-44    1397
# 45-49     988
# 50-54     698
# 55-59     411
# 60-69     398
# 70+        76
# Name: Q1, dtype: int64

# %%
show_countplot("Q2")

# %%
Qno=["Q1","Q2","Q3","Q4","Q5","Q6"]
for i in Qno:
  show_countplot(i)

# %%
question_Q7 = question.filter(regex="Q7")[0].split('-')[0].strip()
question_Q7
# Out:
# 'What programming languages do you use on a regular basis? (Select all that apply)'

# %%
answer_Q7 = answer.filter(regex="Q7")
answer_Q7
# Out:
#       Q7_Part_1 Q7_Part_2 Q7_Part_3  ... Q7_Part_11 Q7_Part_12 Q7_OTHER
# 1        Python         R       SQL  ...     MATLAB        NaN    Other
# 2        Python         R       SQL  ...        NaN        NaN      NaN
# 3           NaN       NaN       NaN  ...        NaN        NaN      NaN
# 4        Python       NaN       SQL  ...        NaN        NaN      NaN
# 5        Python       NaN       NaN  ...        NaN        NaN      NaN
# ...         ...       ...       ...  ...        ...        ...      ...
# 20032       NaN       NaN       NaN  ...        NaN        NaN      NaN
# 20033    Python       NaN       NaN  ...        NaN        NaN      NaN
# 20034    Python       NaN       NaN  ...        NaN        NaN      NaN
# 20035    Python       NaN       SQL  ...        NaN        NaN      NaN
# 20036    Python       NaN       NaN  ...        NaN        NaN      NaN
#
# [20036 rows x 13 columns]

# %%
ans_desc = answer_Q7.describe()
ans_desc
# Out:
#        Q7_Part_1 Q7_Part_2 Q7_Part_3  ... Q7_Part_11 Q7_Part_12 Q7_OTHER
# count      15530      4277      7535  ...       2217        206     1945
# unique         1         1         1  ...          1          1        1
# top       Python         R       SQL  ...     MATLAB       None    Other
# freq       15530      4277      7535  ...       2217        206     1945
#
# [4 rows x 13 columns]

# %%
ans_desc.iloc[[0,2]]
df1 = ans_desc.iloc[[2,0]].T
a = df1.sort_values("count", ascending=False)
a
# Out:
#                    top  count
# Q7_Part_1       Python  15530
# Q7_Part_3          SQL   7535
# Q7_Part_2            R   4277
# Q7_Part_5          C++   3827
# Q7_Part_6         Java   3367
# Q7_Part_4            C   3315
# Q7_Part_7   Javascript   2995
# Q7_Part_11      MATLAB   2217
# Q7_OTHER         Other   1945
# Q7_Part_10        Bash   1776
# Q7_Part_8        Julia    262
# Q7_Part_12        None    206
# Q7_Part_9        Swift    198

# %%
def question_title(question_number):
  if question_number in question.index:
    return question[question_number]
  else:
    return question.filter(regex=question_number)[0].split('-')[0].strip()

# %%
def show_countplot(question_number,order=None):
  if not order:
    order = answer[question_number].value_counts().index
  plt.figure(figsize=(10,8))
  sns.countplot(data=answer, y=question_number, order=order, palette="Blues_r").set_title(question[question_number])

# %%
def show_barplot(question_number):
  b = answer.filter(regex=question_number).describe().iloc[[2,0]].T.sort_values("count", ascending=False)
  plt.figure(figsize=(10,8))
  sns.barplot(data=b, y="top", x="count", palette="Blues_r").set_title(question_title(question_number))

# %%
sns.barplot(data=df1, y="top", x="count", palette="Blues_r").set_title(question_Q7)
# Out:
# Text(0.5, 1.0, 'What programming languages do you use on a regular basis? (Select all that apply)')

# %%
show_barplot("Q7")

# %%
def show_plot(question_number):
  if question_number in question.index:
    show_countplot(question_number, order=None)
  else:
    show_barplot(question_number)

# %%
show_plot("Q7")

# %%
show_plot("Q3")
